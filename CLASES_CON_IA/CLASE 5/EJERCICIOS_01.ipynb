# %% [markdown]
# ### EJERCICIOS

# %%
#E1
precios = [120,45,89,300,15,60]
list_c = [precio * 0.9 for precio in precios]

#E2
estudiantes = {"Ana":15,"Luis":8,"Eva":18,"Marco":12}
dict_c = {alumno for alumno in estudiantes if estudiantes[alumno] > 11 }

#3
gen_exp = ((i+1) * (i+1) for i in range(15) if not (i+1) % 3 == 0)
lista_00 = list(gen_exp)

#4
def promedio_seguro(lista):
    try:
        promedio = sum(lista) / len(lista)
        return promedio

    except ZeroDivisionError:
        print("Lista vacía")
    except TypeError:
        print("Error de tipo")

#5++
class Producto:
    def __init__(self,nombre,precio,stock):
        self.nombre = nombre
        self.precio = precio
        self.stock = stock
    def vender(self,cantidad):

        try:
            if cantidad > self.stock:
                raise ValueError ("Error")
            else:
                return self.stock - cantidad
        except ValueError as e:
            print("Valur Insuficiente")


#6
import numpy as np

resultado = len(np.array([12, 45, 7, 89, 23, 56, 3, 90])[np.array([12, 45, 7, 89, 23, 56, 3, 90]) > np.array([12, 45, 7, 89, 23, 56, 3, 90]).mean()])

#7
aya =[1,2,3]
estecsmr = ["x","y"]

tuplas = [(c,f) for c in aya for f in estecsmr]

#E8
producto1 = Producto("Lapiz",5,3)
producto2 = Producto("Borrador",2,6)
productos = [producto1,producto2]

class INVENTARIO:
    def __init__(self,lista):
        self.lista = lista
    def valor_total(self):
        return sum([producto.precio * producto.stock for producto in self.lista])
        


#E9

temperatura = np.array([22,19,25,30,18,27,21])
temperatura[temperatura > 25] = 25
print(temperatura)

#E10



ventas = [
    {"producto": "Laptop", "cantidad": 3, "precio": 1200},
    {"producto": "Mouse", "cantidad": 5, "precio": 25},
    {"producto": "CPU", "cantidad": 1, "precio": 1200},
]


def procesar_ventas(ventas):
    resultado = {}
    for venta in ventas:
        try:
            producto = venta["producto"]
            subtotal1 = venta["cantidad"] * venta["precio"]
        except KeyError:
            continue

        if producto in resultado:
            resultado[producto] += subtotal1
        else: 
            resultado[producto] = subtotal1

    return resultado

print(procesar_ventas(ventas))
# Out:
# [22 19 25 25 18 25 21]
# {'Laptop': 3600, 'Mouse': 125, 'CPU': 1200}
