# %% [markdown]
# # **Laboratorio 1:** Introducción a Pandas

# %% [markdown]
# ### Cargar las librerías
#
# Importar la librería Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Crear un DataFrame

# %%
#Crear un DataFrame a partir de un diccionario
data = {'Nombre':['Andrea', 'Adrian', 'Jimena', 'Arturo', 'Miguel',],
        'Edad':[17, 17, 19, 17,23],
        'Código':['A01093', 'A01094', 'A01095', 'A01096', 'A01097'],
        'Sexo': ['F','M','F','M','M']}

df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad  Código Sexo
# 0  Andrea    17  A01093    F
# 1  Adrian    17  A01094    M
# 2  Jimena    19  A01095    F
# 3  Arturo    17  A01096    M
# 4  Miguel    23  A01097    M

# %%
lista=[1, 2, 3]
type(lista)
# Out:
# list

# %%
df.head()
# Out:
#    Nombre  Edad  Código Sexo
# 0  Andrea    17  A01093    F
# 1  Adrian    17  A01094    M
# 2  Jimena    19  A01095    F
# 3  Arturo    17  A01096    M
# 4  Miguel    23  A01097    M

# %%
df["Nombre"]
# Out:
# 0    Andrea
# 1    Adrian
# 2    Jimena
# 3    Arturo
# 4    Miguel
# Name: Nombre, dtype: str

# %%
df.columns
# Out:
# Index(['Nombre', 'Edad', 'Código', 'Sexo'], dtype='str')

# %%
df[["Edad", "Código","Nombre"]]
# Out:
#    Edad  Código  Nombre
# 0    17  A01093  Andrea
# 1    17  A01094  Adrian
# 2    19  A01095  Jimena
# 3    17  A01096  Arturo
# 4    23  A01097  Miguel

# %% [markdown]
# ### Ejercicio: Crea un DataFrame con dos columnas: los nombres de los compañeros sentados en tu fila y los nombres de sus mascotas. En caso de que no tengan mascotas debe tenerse un dato faltante NaN en el DataFrame

# %%
import numpy as np

# %%
data={"nombre":["maria", "pepe", "julio"],
      "mascota":["firulais", np.nan, "atena"]}
df_mascotas=pd.DataFrame(data)
df_mascotas
# Out:
#   nombre   mascota
# 0  maria  firulais
# 1   pepe       NaN
# 2  julio     atena

# %%
df_mascotas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nombre   3 non-null      str
#  1   mascota  2 non-null      str
# dtypes: str(2)
# memory usage: 208.0 bytes

# %% [markdown]
# ### Cargar un dataset de una librería

# %%
# Importar la librería seaborn
import seaborn as sns

#Imprimir el nombre de los datasets que tiene la librería seaborn
print (sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Cargamos el dataset titanic
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 100.4 KB

# %%
df.head(13)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       2  female  19.0      0      0  30.00        S   First
# 888         0       2  female   NaN      1      2  23.45        S   Third
# 889         1       2    male  26.0      0      0  30.00        C   First
# 890         0       2    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: str

# %%
df.iloc[890] #posicion de la fila
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                  32.0
# sibsp                   0
# parch                   0
# fare                 7.75
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 890, dtype: object

# %%
df.pclass >1
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: pclass, Length: 891, dtype: bool

# %% [markdown]
# ### Ejercicio: Muestra las columnas class, deck y alive únicamente para los pasajeros que tengan por lo menos 30 años.

# %%
df_1=df.loc[df.age>=30]
df_2=df_1[["class", "deck", "alive"]]
df_2.head()
# Out:
#     class deck alive
# 1   First    C   yes
# 3   First    C   yes
# 4   Third  NaN    no
# 6   First    E    no
# 11  First    C   yes

# %%
df.loc[df.age>=30 , ["class", "deck", "alive"]]
# Out:
#      class deck alive
# 1    First    C   yes
# 3    First    C   yes
# 4    Third  NaN    no
# 6    First    E    no
# 11   First    C   yes
# ..     ...  ...   ...
# 873  Third  NaN    no
# 879  First    C   yes
# 881  Third  NaN    no
# 885  Third  NaN    no
# 890  Third  NaN    no
#
# [330 rows x 3 columns]

# %% [markdown]
# ### Importar un archivo .csv

# %%
data = pd.read_csv("titanic.csv")

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
data_1=data.dropna() #--> LIMPIAR FILAS VACIAS

# %%
data_1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    str
#  4   Sex          183 non-null    str
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    str
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    str
#  11  Embarked     183 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 18.6 KB

# %%
data.Age.fillna(0)
data["Age"]=data.Age.fillna(0) #->Rellenar los datas que faltan con 0
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data = pd.read_csv("titanic.csv")
data["Age"] = data["Age"].replace(np.nan, 0)
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male   0.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
import emoji # type: ignore
print(emoji.emojize('Python is :thumbs_up:'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import emoji
#       2 print(emoji.emojize('Python is :thumbs_up:'))
#
# ModuleNotFoundError: No module named 'emoji'
